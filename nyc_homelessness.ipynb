# %% [markdown]
# # NYC Homeless Population Analysis
#
# ## Introduction
#
# This project focuses on analyzing daily data of the NYC homeless population collected from the Department of Homeless Services (DHS). The aim is to gain insights into trends, patterns, and potential factors influencing homelessness in New York City.
#
# ## Data Overview
#
# The dataset, `DHS_Homeless_Shelter_Census.csv`, contains daily records of the NYC homeless shelter census, including metrics such as the number of individuals, families, and single adults in the system. This analysis will begin with an exploratory data analysis (EDA) to understand the dataset's structure, identify missing values, and uncover preliminary trends.
#
# ---
#
# ## Exploratory Data Analysis (EDA)
#
# The EDA will include the following steps:
# 1. Loading and inspecting the dataset.
# 2. Checking for missing values and data types.
# 3. Descriptive statistics for numerical columns.
# 4. Visualizing trends in the dataset.
#
# ---
#
# ## Objectives
#
# 1. Understand the scope of homelessness in NYC based on the data.
# 2. Identify seasonal or daily trends in shelter usage.
# 3. Provide actionable insights for policymakers and stakeholders.
#
# ---
#
# ## Getting Started
#
# The first step is loading the data and performing an exploratory analysis to understand its structure and contents.

# %%
data.dtypes
# Out:
# Total Individuals         int64
# Single Adults             int64
# Families with Children    int64
# Adult Families            int64
# Year                      int32
# Month                     int32
# dtype: object

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Chart 1: Total Individuals Over Time
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['Total Individuals'], label='Trend: Total Individuals Over Time', color='blue', linewidth=2)
plt.title("Total Individuals in NYC Shelters Over Time\n(Trend line represents the change over time)", fontsize=14)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Number of Individuals", fontsize=12)
plt.legend(loc="upper left", fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# Chart 2: Single Adults Over Time
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['Single Adults'], label='Trend: Single Adults Over Time', color='green', linewidth=2)
plt.title("Single Adults in NYC Shelters Over Time\n(Trend line represents the change over time)", fontsize=14)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Number of Single Adults", fontsize=12)
plt.legend(loc="upper left", fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# Chart 3: Families with Children Over Time
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['Families with Children'], label='Trend: Families with Children Over Time', color='orange', linewidth=2)
plt.title("Families with Children in NYC Shelters Over Time\n(Trend line represents the change over time)", fontsize=14)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Number of Families with Children", fontsize=12)
plt.legend(loc="upper left", fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# Chart 4: Adult Families Over Time
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['Adult Families'], label='Trend: Adult Families Over Time', color='red', linewidth=2)
plt.title("Adult Families in NYC Shelters Over Time\n(Trend line represents the change over time)", fontsize=14)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Number of Adult Families", fontsize=12)
plt.legend(loc="upper left", fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# Chart 5: Comparison of Shelter Categories Over Time
plt.figure(figsize=(12, 6))
for col, color in zip(['Single Adults', 'Families with Children', 'Adult Families'], ['green', 'orange', 'red']):
    plt.plot(data.index, data[col], label=f"Trend: {col}", linewidth=2, color=color)
plt.title("Comparison of Shelter Categories Over Time\n(Trend lines represent changes over time)", fontsize=14)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Number of Individuals", fontsize=12)
plt.legend(loc="upper left", fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
