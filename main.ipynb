# %%
# Import required libraries and utilities
import os
import importlib
import utilities
importlib.reload(utilities)
from utilities import (
    load_data,
    preprocess_data,
    summarize_data,
    plot_time_series,
    plot_distribution,
    correlation_analysis,
    plot_monthly_trends,
    plot_yearly_trends,
    generate_report,
)


# File Path
file_path = 'DHS_Homeless_Shelter_Census.csv'

# Step 1: Load Data
print("📂 Loading data...")
df = load_data(file_path)
print("✅ Data loaded successfully!\n")

# Step 2: Preprocess Data
print("🔧 Preprocessing data...")
df = preprocess_data(df)
print("✅ Data preprocessing completed!\n")

# Step 3: Summarize Data
print("📊 Generating summary...")
summary = summarize_data(df)
print("✅ Summary generated successfully!")
print("\n--- Dataset Summary ---")
print(f"Missing Values:\n{summary['missing_values']}")
print(f"Data Types:\n{summary['data_types']}")
print(f"Descriptive Statistics:\n{summary['descriptive_stats']}")
print(f"Date Range: {summary['date_range'][0]} to {summary['date_range'][1]}")
print(f"Unique Dates: {summary['unique_dates']}")

# Step 4: Visualizations
print("📈 Generating visualizations...")
plot_time_series(df, 'total_individuals_in_shelter', "Total Individuals in Shelter Over Time")
plot_distribution(df, 'total_single_adults_in_shelter')
plot_monthly_trends(df)
plot_yearly_trends(df)

# Step 5: Generate Report
print("📝 Generating report...")
generate_report(df)
print("✅ Report generated successfully!\n")

print("🎉 Analysis completed successfully!")
# Out:
# 📂 Loading data...
# ✅ Data loaded successfully!
#
# 🔧 Preprocessing data...
# ✅ Data preprocessing completed!
#
# 📊 Generating summary...
# ✅ Summary generated successfully!
#
# --- Dataset Summary ---
# Missing Values:
# date_of_census                       0
# total_individuals_in_shelter         0
# total_single_adults_in_shelter       0
# families_with_children_in_shelter    0
# adult_families_in_shelter            0
# dtype: int64
# Data Types:
# date_of_census                       datetime64[ns]
# total_individuals_in_shelter                  int64
# total_single_adults_in_shelter                int64
# families_with_children_in_shelter             int64
# adult_families_in_shelter                     int64
# dtype: object
# Descriptive Statistics:
#                       date_of_census  total_individuals_in_shelter  \
# count                           4065                   4065.000000
# mean   2019-05-04 03:58:45.608856064                  60695.062485
# min              2013-08-21 00:00:00                  44586.000000
# 25%              2016-07-09 00:00:00                  54173.000000
# 50%              2019-05-17 00:00:00                  58450.000000
# 75%              2022-03-01 00:00:00                  60529.000000
# max              2024-12-05 00:00:00                  89558.000000
# std                              NaN                  11650.433753
#
#        total_single_adults_in_shelter  families_with_children_in_shelter  \
# count                     4065.000000                        4065.000000
# mean                     15818.405904                       12471.357442
# min                       9610.000000                        8180.000000
# 25%                      13119.000000                       10781.000000
# 50%                      16222.000000                       12169.000000
# 75%                      17926.000000                       12796.000000
# max                      23161.000000                       19641.000000
# std                       3338.685572                        2854.209628
#
#        adult_families_in_shelter
# count                4065.000000
# mean                 2190.988438
# min                  1385.000000
# 25%                  1897.000000
# 50%                  2233.000000
# 75%                  2489.000000
# max                  3101.000000
# std                   364.787525
# Date Range: 2013-08-21 00:00:00 to 2024-12-05 00:00:00
# Unique Dates: 4050
# 📈 Generating visualizations...
# 📝 Generating report...
# ============================================================
# 🌟  HOMELESS SHELTER CENSUS REPORT  🌟
# ============================================================
# 🗓  Date Range:
#     From 2013-08-21 to 2024-12-05
#
# 📊 Key Statistics:
#     - Average Total Individuals In Shelter: 60,695.06
#     - Latest Total Individuals In Shelter: 87,226
#     - Average Total Single Adults In Shelter: 15,818.41
#     - Latest Total Single Adults In Shelter: 21,510
#     - Average Families With Children In Shelter: 12,471.36
#     - Latest Families With Children In Shelter: 19,142
#     - Average Adult Families In Shelter: 2,190.99
#     - Latest Adult Families In Shelter: 1,874
#
# 📅 Year Statistics:
#     - Earliest Year: 2013
#     - Latest Year: 2024
#
# 🔗 Correlation Analysis:
#                                    total_individuals_in_shelter  \
# total_individuals_in_shelter                           1.000000
# total_single_adults_in_shelter                         0.600892
# families_with_children_in_shelter                      0.982040
# adult_families_in_shelter                              0.374919
# year                                                   0.510142
#
#                                    total_single_adults_in_shelter  \
# total_individuals_in_shelter                             0.600892
# total_single_adults_in_shelter                           1.000000
# families_with_children_in_shelter                        0.468173
# adult_families_in_shelter                                0.147908
# year                                                     0.957419
#
#                                    families_with_children_in_shelter  \
# total_individuals_in_shelter                                0.982040
# total_single_adults_in_shelter                              0.468173
# families_with_children_in_shelter                           1.000000
# adult_families_in_shelter                                   0.353420
# year                                                        0.391237
#
#                                    adult_families_in_shelter      year
# total_individuals_in_shelter                        0.374919  0.510142
# total_single_adults_in_shelter                      0.147908  0.957419
# families_with_children_in_shelter                   0.353420  0.391237
# adult_families_in_shelter                           1.000000 -0.087590
# year                                               -0.087590  1.000000
# ============================================================
# ✅ Report generated successfully!
# ✅ Report generated successfully!
#
# 🎉 Analysis completed successfully!
